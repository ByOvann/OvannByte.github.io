# %% [markdown]
# <a href="https://colab.research.google.com/github/ByOvann/OvannByte.github.io/blob/main/Klasifikasi_MNIST_Menggunakan_Deep_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from sklearn.metrics import classification_report

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("Train shape:", x_train.shape, y_train.shape)
print("Test shape:", x_test.shape, y_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train shape: (60000, 28, 28) (60000,)
# Test shape: (10000, 28, 28) (10000,)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ...

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5322 - loss: 1.4320 - val_accuracy: 0.8458 - val_loss: 0.5229
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8581 - loss: 0.4861 - val_accuracy: 0.8959 - val_loss: 0.3655
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8938 - loss: 0.3689 - val_accuracy: 0.9084 - val_loss: 0.3157
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9064 - loss: 0.3252 - val_accuracy: 0.9172 - val_loss: 0.2915
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9147 - loss: 0.2931 - val_accuracy: 0.9247 - val_loss: 0.2625
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9211 - loss: 0.2698 - val_accuracy: 0.9297 - val_loss: 0.2450
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9272 - loss: 0.2523 - val_accuracy: 0.9346 - val_loss: 0.2272
# Epoch 8/10
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy:", test_acc)
# Out:
# Test Accuracy: 0.9444000124931335

# %%
y_pred = model.predict(x_test)
y_pred_classes = y_pred.argmax(axis=1)

print(classification_report(y_test, y_pred_classes))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       980
#            1       0.97      0.98      0.98      1135
#            2       0.93      0.95      0.94      1032
#            3       0.92      0.94      0.93      1010
#            4       0.94      0.95      0.94       982
#            5       0.92      0.91      0.92       892
#            6       0.96      0.96      0.96       958
#            7       0.95      0.95      0.95      1028
#            8       0.94      0.90      0.92       974
#            9       0.96      0.90      0.93      1009
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
import numpy as np

sample = x_test[0].reshape(1, 28, 28)
prediction = model.predict(sample)

print("Predicted:", prediction.argmax())
print("Actual:", y_test[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Predicted: 7
# Actual: 7

# %% [markdown]
# ## Kesimpulan
# Model Deep Learning (DNN) berhasil mengklasifikasikan angka tulisan tangan
# pada dataset MNIST (0-9) dengan tingkat akurasi yang tinggi.
# Hasil ini menunjukkan bahwa Deep Neural Network efektif
# untuk tugas klasifikasi citra sederhana.
